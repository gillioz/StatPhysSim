# %%
from Ising import *
# %matplotlib notebook

# %%
β = 0.32

σ, ϵ = Ising_MC(100, β)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 100%|█████████████████████████████████████████| 100/100 [00:07<00:00, 12.91it/s]

# %%
Ising_beta_c
# Out:
# 0.44068679350977147
